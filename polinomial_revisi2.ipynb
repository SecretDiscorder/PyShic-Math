# %% [markdown]
# <a href="https://colab.research.google.com/github/SecretDiscorder/PyShic-Math/blob/main/polinomial_revisi2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from sympy import sympify, simplify

# ... (The rest of your code remains the same)

import sympy as sp

def add_implicit_multiplication(expression):
    # Tambahkan operator '*' eksplisit sebelum variabel tanpa operator di antara mereka
    # Misalnya, ubah '3x+5y' menjadi '3*x+5*y'
    operators = {'x', 'y'}
    new_expr = ""
    for i, char in enumerate(expression):
        new_expr += char
        if char.isalpha() and i < len(expression) - 1 and expression[i+1] not in operators:
            new_expr += '*'
    return new_expr

def plot_spldv(m, b, label):
    x_vals = np.linspace(-10, 10, 1000)
    y_vals = m * x_vals + b

    plt.plot(x_vals, y_vals, label=label)
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.grid(True)
def main():
    x = sp.Symbol('x')
    f_x = sp.Function('f')(x)
    g_x = sp.Function('g')(x)

    print("Masukkan persamaan fungsi f(x) dan g(x) serta operator matematika.")
    print("Contoh: 'f(x) = x**2 + 3*x - 4', 'g(x) = 2*x + 1', dan operator '+', '-', '*', '/'.")

    f_equation_str = input("Masukkan persamaan fungsi f(x): ")
    g_equation_str = input("Masukkan persamaan fungsi g(x): ")
    operator = input("Masukkan operator matematika (+, -, *, /): ")

    f_x_expr = sp.sympify(f_equation_str.replace(' ', ''))
    g_x_expr = sp.sympify(g_equation_str.replace(' ', ''))

    result_expr = None
    if operator == '+':
        result_expr = f_x_expr + g_x_expr
    elif operator == '-':
        result_expr = f_x_expr - g_x_expr
    elif operator == '*':
        result_expr = f_x_expr * g_x_expr
    elif operator == '/':
        result_expr, _ = sp.div(f_x_expr, g_x_expr)
    elif operator == '%':
        quotient, remainder = sp.div(f_x_expr, g_x_expr)
        result_expr = remainder
    else:
        print("Operator matematika tidak valid. Silakan gunakan '+', '-', '*', atau '/'.")
        return

    result_expr = sp.expand(result_expr)

    print("\nHasil Operasi:")
    print(f"f(x) = {f_x_expr}")
    print(f"g(x) = {g_x_expr}")
    print(f"Hasil (f(x) {operator} g(x)) = {result_expr}\n")

    m_f_x = f_x_expr.as_coefficients_dict(x)[x]
    b_f_x = f_x_expr.subs(x, 0)
    m_g_x = g_x_expr.as_coefficients_dict(x)[x]
    b_g_x = g_x_expr.subs(x, 0)

    x_vals = np.linspace(-3, 3, 1000)

    # Evaluate the expressions for f(x), g(x), and result_expr for the given x values
    f_x_vals = np.array([f_x_expr.subs(x, val) for val in x_vals])
    g_x_vals = np.array([g_x_expr.subs(x, val) for val in x_vals])
    result_vals = np.array([result_expr.subs(x, val) for val in x_vals])

    plt.figure(figsize=(10, 6))

    # Plot the curves for f(x), g(x), and result_expr
    plt.plot(x_vals, f_x_vals, label='f(x)')
    plt.plot(x_vals, g_x_vals, label='g(x)')
    plt.plot(x_vals, result_vals, label=f'f(x) {operator} g(x)')

    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.title(f'Grafik SPLDV (f(x), g(x), dan f(x) {operator} g(x))')
    plt.grid(True)
    plt.legend()
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Masukkan persamaan fungsi f(x) dan g(x) serta operator matematika.
# Contoh: 'f(x) = x**2 + 3*x - 4', 'g(x) = 2*x + 1', dan operator '+', '-', '*', '/'.
# Masukkan persamaan fungsi f(x): x**3-1*x**2
# Masukkan persamaan fungsi g(x): 2
# Masukkan operator matematika (+, -, *, /): +
#
# Hasil Operasi:
# f(x) = x**3 - x**2
# g(x) = 2
# Hasil (f(x) + g(x)) = x**3 - x**2 + 2
